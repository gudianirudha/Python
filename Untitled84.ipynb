# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.goodreads.com/quotes/tag/{}"

# %%
res=url.format("funny")

# %%
result=requests.get(res)

# %%
result.content
# Out:
# b'<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Funny Quotes (8032 quotes)</title>\n\n<meta content=\'8032 quotes have been tagged as funny: Chris Rock: \xe2\x80\x98You know the world is going crazy when the best rapper is a white guy, the best golfer is a black guy...\' name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/quotes/tag/funny\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "280-2743804-0483152";\n    var ue_id = "YB8PN0JC7BDN12FNWFDK";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:a
# ...

# %%
soup=BeautifulSoup(result.text)

# %%
soup.p
# Out:
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>

# %%
# Out:
# <bound method Tag.childGenerator of <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage">
# <head>
# <title>Funny Quotes (8032 quotes)</title>
# <meta content="8032 quotes have been tagged as funny: Chris Rock: ‘You know the world is going crazy when the best rapper is a white guy, the best golfer is a black guy..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/quotes/tag/funny" rel="canonical"/>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
#     var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "280-2743804-0483152";
#     var ue_id = "YB8PN0JC7BDN12FNWFDK";
#
# ...
