# %%
print("line 1")
print("line 2")
# line 3 is an empty return - the default when no arguments
print()
print(                                           )
print("line            4")
# Out:
# line 1
# line 2
#
#
# line            4

# %%
print(\"What's that"? isn't a specific question)
# Out:
#   File "<ipython-input-20-eb95f676c2d3>", line 1
#     print(\"What's that"? isn't a specific question)
#                                                     ^
# SyntaxError: unexpected character after line continuation character
